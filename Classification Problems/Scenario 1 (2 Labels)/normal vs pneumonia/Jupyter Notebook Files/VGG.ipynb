# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16,ResNet50V2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os

# %%
import sys
sys.argv[1:]
sys.argv[1:] = '-d dataset -p plot -m model'.split()

# %%
# construct the argument parser and parse the arguments
ap = argparse.ArgumentParser()
ap.add_argument("-d", "--dataset", required=True,help="path to input dataset")
ap.add_argument("-p", "--plot", type=str, default="plot.png",help="path to output loss/accuracy plot")
ap.add_argument("-m", "--model", type=str, default="covid19.model",help="path to output loss/accuracy plot")

args = vars(ap.parse_args())
# initialize the initial learning rate, number of epochs to train for,
# and batch size
INIT_LR = 1e-3
EPOCHS = 25
BS = 8

# %%
# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print("[INFO] loading images...")
imagePaths = list(paths.list_images(args["dataset"]))
data = []
labels = []
# loop over the image paths
for imagePath in imagePaths:
	# extract the class label from the filename
	label = imagePath.split(os.path.sep)[-2]
	# load the image, swap color channels, and resize it to be a fixed
	# 224x224 pixels while ignoring aspect ratio
	image = cv2.imread(imagePath)
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	image = cv2.resize(image, (224, 224))
	# update the data and labels lists, respectively
	data.append(image)
	labels.append(label)
# convert the data and labels to NumPy arrays while scaling the pixel
# intensities to the range [0, 1]
data = np.array(data) / 255.0
labels = np.array(labels)
# Out:
# [INFO] loading images...

# %%
print(len(labels))
print(len(data))
# Out:
# 425
# 425

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)
# initialize the training data augmentation object

# %%
trainAug = ImageDataGenerator(
    rotation_range=15,
    fill_mode="nearest")

# %%
print("Train Data:")
print(len(trainX))
print("Train labels:")
print(len(trainY))
print("Test Data:")
print(len(testX))
print("Test labels:")
print(len(testY))
# Out:
# Train Data:
# 340
# Train labels:
# 340
# Test Data:
# 85
# Test labels:
# 85

# %%
# load the VGG16 network, ensuring the head FC layer sets are left
# off
baseModel = VGG16(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(224, 224, 3)))
# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(2, 2))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(64, activation="relu")(headModel)
headModel = Dropout(0.3)(headModel)
headModel = Dense(2, activation="softmax")(headModel)
# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)
# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process

# %%
for layer in baseModel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                294976
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 15,009,794
# Trainable params: 295,106
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# compile our model
opt = Adam(lr=0.001, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# train the head of the network
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("2classvggBacvsViru.hdf5", monitor='loss', verbose=1,
                             save_best_only=True, mode='auto', period=1)
H = model.fit_generator(
	trainAug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS,callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-12-5fa9a0cd84d5>:14: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/25
# 42/42 [==============================] - ETA: 0s - loss: 0.6990 - accuracy: 0.6012
# Epoch 00001: loss improved from inf to 0.69903, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 71s 2s/step - loss: 0.6990 - accuracy: 0.6012 - val_loss: 0.6510 - val_accuracy: 0.6353
# Epoch 2/25
# 42/42 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.7139
# Epoch 00002: loss improved from 0.69903 to 0.57932, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 96s 2s/step - loss: 0.5793 - accuracy: 0.7139 - val_loss: 0.6847 - val_accuracy: 0.6588
# Epoch 3/25
# 42/42 [==============================] - ETA: 0s - loss: 0.5884 - accuracy: 0.6928
# Epoch 00003: loss did not improve from 0.57932
# 42/42 [==============================] - 85s 2s/step - loss: 0.5884 - accuracy: 0.6928 - val_loss: 0.6100 - val_accuracy: 0.6706
# Epoch 4/25
# 42/42 [==============================] - ETA: 0s - loss: 0.5620 - accuracy: 0.7108
# Epoch 00004: loss improved from 0.57932 to 0.56196, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 82s 2s/step - loss: 0.5620 - accuracy: 0.7108 - val_loss: 0.6162 - val_accuracy: 0.6588
# Epoch 5/25
# 42/42 [==============================] - ETA: 0s - loss: 0.5381 - accuracy: 0.7259
# Epoch 00005: loss improved from 0.56196 to 0.53807, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 97s 2s/step - loss: 0.5381 - accuracy: 0.7259 - val_loss: 0.6221 - val_accuracy: 0.6471
# Epoch 6/25
# 42/42 [==============================] - ETA: 0s - loss: 0.5223 - accuracy: 0.7139
# Epoch 00006: loss improved from 0.53807 to 0.52230, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 94s 2s/step - loss: 0.5223 - accuracy: 0.7139 - val_loss: 0.6792 - val_accuracy: 0.6824
# Epoch 7/25
# 42/42 [==============================] - ETA: 0s - loss: 0.5250 - accuracy: 0.7440
# Epoch 00007: loss did not improve from 0.52230
# 42/42 [==============================] - 100s 2s/step - loss: 0.5250 - accuracy: 0.7440 - val_loss: 0.6262 - val_accuracy: 0.6941
# Epoch 8/25
# 42/42 [==============================] - ETA: 0s - loss: 0.5224 - accuracy: 0.7560
# Epoch 00008: loss did not improve from 0.52230
# 42/42 [==============================] - 100s 2s/step - loss: 0.5224 - accuracy: 0.7560 - val_loss: 0.5692 - val_accuracy: 0.7059
# Epoch 9/25
# 42/42 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.7711
# Epoch 00009: loss improved from 0.52230 to 0.49291, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 83s 2s/step - loss: 0.4929 - accuracy: 0.7711 - val_loss: 0.5729 - val_accuracy: 0.6706
# Epoch 10/25
# 42/42 [==============================] - ETA: 0s - loss: 0.4796 - accuracy: 0.7861
# Epoch 00010: loss improved from 0.49291 to 0.47960, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 84s 2s/step - loss: 0.4796 - accuracy: 0.7861 - val_loss: 0.6743 - val_accuracy: 0.6706
# Epoch 11/25
# 42/42 [==============================] - ETA: 0s - loss: 0.4410 - accuracy: 0.7831
# Epoch 00011: loss improved from 0.47960 to 0.44097, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 84s 2s/step - loss: 0.4410 - accuracy: 0.7831 - val_loss: 0.6262 - val_accuracy: 0.7294
# Epoch 12/25
# 42/42 [==============================] - ETA: 0s - loss: 0.4861 - accuracy: 0.7801
# Epoch 00012: loss did not improve from 0.44097
# 42/42 [==============================] - 109s 3s/step - loss: 0.4861 - accuracy: 0.7801 - val_loss: 0.5471 - val_accuracy: 0.7059
# Epoch 13/25
# 42/42 [==============================] - ETA: 0s - loss: 0.4177 - accuracy: 0.8042
# Epoch 00013: loss improved from 0.44097 to 0.41775, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 112s 3s/step - loss: 0.4177 - accuracy: 0.8042 - val_loss: 0.6183 - val_accuracy: 0.7176
# Epoch 14/25
# 42/42 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.7741
# Epoch 00014: loss did not improve from 0.41775
# 42/42 [==============================] - 111s 3s/step - loss: 0.4601 - accuracy: 0.7741 - val_loss: 0.6166 - val_accuracy: 0.7294
# Epoch 15/25
# 42/42 [==============================] - ETA: 0s - loss: 0.4413 - accuracy: 0.8133
# Epoch 00015: loss did not improve from 0.41775
# 42/42 [==============================] - 113s 3s/step - loss: 0.4413 - accuracy: 0.8133 - val_loss: 0.5224 - val_accuracy: 0.6941
# Epoch 16/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.7892
# Epoch 00016: loss improved from 0.41775 to 0.38338, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 114s 3s/step - loss: 0.3834 - accuracy: 0.7892 - val_loss: 0.6064 - val_accuracy: 0.7412
# Epoch 17/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8313
# Epoch 00017: loss improved from 0.38338 to 0.38337, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 110s 3s/step - loss: 0.3834 - accuracy: 0.8313 - val_loss: 0.5893 - val_accuracy: 0.7529
# Epoch 18/25
# 42/42 [==============================] - ETA: 0s - loss: 0.4032 - accuracy: 0.8283
# Epoch 00018: loss did not improve from 0.38337
# 42/42 [==============================] - 106s 3s/step - loss: 0.4032 - accuracy: 0.8283 - val_loss: 0.5068 - val_accuracy: 0.6941
# Epoch 19/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8554
# Epoch 00019: loss improved from 0.38337 to 0.34647, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 107s 3s/step - loss: 0.3465 - accuracy: 0.8554 - val_loss: 0.5352 - val_accuracy: 0.7176
# Epoch 20/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3648 - accuracy: 0.8584
# Epoch 00020: loss did not improve from 0.34647
# 42/42 [==============================] - 107s 3s/step - loss: 0.3648 - accuracy: 0.8584 - val_loss: 0.5117 - val_accuracy: 0.7176
# Epoch 21/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3445 - accuracy: 0.8554
# Epoch 00021: loss improved from 0.34647 to 0.34447, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 110s 3s/step - loss: 0.3445 - accuracy: 0.8554 - val_loss: 0.5302 - val_accuracy: 0.7294
# Epoch 22/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3192 - accuracy: 0.8675
# Epoch 00022: loss improved from 0.34447 to 0.31915, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 109s 3s/step - loss: 0.3192 - accuracy: 0.8675 - val_loss: 0.4988 - val_accuracy: 0.7176
# Epoch 23/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3406 - accuracy: 0.8313
# Epoch 00023: loss did not improve from 0.31915
# 42/42 [==============================] - 109s 3s/step - loss: 0.3406 - accuracy: 0.8313 - val_loss: 0.5114 - val_accuracy: 0.7412
# Epoch 24/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3253 - accuracy: 0.8464
# Epoch 00024: loss did not improve from 0.31915
# 42/42 [==============================] - 105s 3s/step - loss: 0.3253 - accuracy: 0.8464 - val_loss: 0.4801 - val_accuracy: 0.7529
# Epoch 25/25
# 42/42 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.8795
# Epoch 00025: loss improved from 0.31915 to 0.31647, saving model to 2classvggBacvsViru.hdf5
# 42/42 [==============================] - 110s 3s/step - loss: 0.3165 - accuracy: 0.8795 - val_loss: 0.4974 - val_accuracy: 0.7529

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)
# show a nicely formatted classification report
print(classification_report(testY.argmax(axis=1), predIdxs,
	target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
#                    precision    recall  f1-score   support
#
# pnemonia_bacteria       0.72      0.86      0.78        44
#    pnemonia_virus       0.81      0.63      0.71        41
#
#          accuracy                           0.75        85
#         macro avg       0.76      0.75      0.75        85
#      weighted avg       0.76      0.75      0.75        85

# %%
# compute the confusion matrix and and use it to derive the raw
# accuracy, sensitivity, and specificity
cm = confusion_matrix(testY.argmax(axis=1), predIdxs)
total = sum(sum(cm)) 
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
# show the confusion matrix, accuracy, sensitivity, and specificity
print(cm)
print("acc: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# [[38  6]
#  [15 26]]
# acc: 0.7529
# sensitivity: 0.8636
# specificity: 0.6341

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on COVID-19 Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig(args["plot"])

# %%
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('TRUE LABEL')
    plt.xlabel('PREDICTED LABEL')
    plt.tight_layout()
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cm, classes=['covid','pnemonia_virus','pnemonia_bacteria','normal'],
                      title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
# [[38  6]
#  [15 26]]

# %%
model.save("vggmodel(bacvsvirus)")
# Out:
# WARNING:tensorflow:From /Users/pawelpratyush/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: vggmodel(bacvsvirus)/assets

# %%
from tensorflow.keras.models import save_model
save_model(model,filepath='./vggbacvsvir',save_format='h5')
